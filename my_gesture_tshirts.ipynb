# %%
from IPython.display import Image
Image("./my_gesture_tshirts.png")

# %%
# %matplotlib inline
import numpy as np
import math
import matplotlib.pyplot as plt

# graph matrix
n_cols = 5
n_rows = 3
plt.figure(figsize=(180, 300))

# generate x
# x = np.arange(-10, 10, 0.01)
a = 2"np.pi
x = np.linspace(-a, a, 101) 


# 
def graph(x, y):
    plt.subplot(n_rows, n_cols, i+1)
    plt.grid()
    plt.title(f)
    plt.ylim(-a, a)
    plt.xlim(-a, a)
    plt.tight_layout()
    plt.plot(x, y)

# %%
# 円を作画するためにベクトルを生成する
x = np.reshape(x, (x.shape[0], 1))

def generateVec(x, a):
    # zeroのベクトルを生成
    x_vec = np.zeros((x.shape))
    y_vec = np.zeros((x.shape))
    
    for i in range(x.shape[0]):
        x_vec[i] = a * np.cos(x[i])
        y_vec[i] = a * np.sin(x[i])
        # data = np.concatenate((x_vec, y_vec),  axis=1)
    return x_vec, y_vec

# %%
func_dict={}

func_dict["x"] = x
func_dict["x^2"] = pow(x, 2)
func_dict["x^3"]= pow(x, 3)
func_dict["sin x"] = np.sin(x)
func_dict["cos x"] = np.cos(x)
func_dict["tan x"]=np.tan(x)
func_dict["cot x"] = 1/np.tan(x)
func_dict["1/x"] = 1/x
func_dict["-1/x"]= -1/x
func_dict["|x|"] = np.abs(x)
func_dict["-|x|"] = - np.abs(x)
func_dict["-x"]= -x
func_dict["log x"] = np.log2(x)
func_dict["a^x"] = pow(a, x)
func_dict["x^2+y^2=a^2"]= 0

# 各関数の計算
i=0

for f in func_dict:

    if f == "x^2+y^2=a^2":
        x, y = generateVec(x, a)
    else:
        x, y = x, func_dict[f]
    
    graph(x, y)
    i=i+1
# Out:
# /var/folders/6f/dzlpy9kd3xxgf9lphzpf8cqc0000gn/T/ipykernel_33326/1375952544.py:15: RuntimeWarning: invalid value encountered in log2
#   func_dict["log x"] = np.log2(x)

# %%
fig.savefig('my_gesture_tshirts.png')
